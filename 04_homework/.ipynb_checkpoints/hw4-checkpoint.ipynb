# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from scipy.special import legendre
from scipy.special import hermite
import copy
import pandas as pd
from scipy import integrate
from scipy.special import comb
from scipy.integrate import quad

# %%
'''
https://people.sc.fsu.edu/~jburkardt/py_src/monomial/monomial.py
Finds the next monomial multi-index, as explained in the lecture

'''

def next_monomial(m,x):
    j = 0

    for i in range ( 1, m ):
        if ( 0 < x[i] ):
            j = i
            break

    if ( j == 0 ):
        t = x[0]
        x[0] = 0
        x[m-1] = t + 1
    elif ( j < m - 1 ):
        x[j] = x[j] - 1
        t = x[0] + 1;
        x[0] = 0;
        x[j-1] = x[j-1] + t
    elif ( j == m - 1 ):
        t = x[0]
        x[0] = 0
        x[j-1] = t + 1
        x[j] = x[j] - 1

    return x

# %%
def f(z1, z2):
    return -abs(z1)**3*z2+np.exp(-(z1-0.5)**2-0.25*z2**2)

# %%
M = 1000000
Z = np.zeros((M,2))



Z[:,0] = np.random.uniform(size=M) * 2 - 1
Z[:,1] = np.random.uniform(size=M) * 2 - 1



f_real = f(Z[:,0],Z[:,1])

# %%
x = Z[:,0]
y = f_real

ax1 = sns.jointplot(x=x, y=y)
ax1.ax_joint.cla()
plt.sca(ax1.ax_joint)

plt.hist2d(x, y, bins=(100, 100), cmap=cm.jet);

# %%
x = Z[:,1]
y = f_real

ax1 = sns.jointplot(x=x, y=y)
ax1.ax_joint.cla()
plt.sca(ax1.ax_joint)

plt.hist2d(x, y, bins=(100, 100), cmap=cm.jet);

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(Z[:,0], Z[:,1], f_real)

# %%
N = 2
M = N+1
D=2

# %%
x, w = np.polynomial.legendre.leggauss(M)

#x are sample points
#w are the weights
print(x)
print(w)
# Out:
# [-0.77459667  0.          0.77459667]
# [0.55555556 0.88888889 0.55555556]

# %%
c=np.zeros(N+1); g=np.zeros(N+1);

# %%
# computational grid
l =-1
r=1
dz=0.001;

z=np.linspace(l,r,int((r-l) / dz));
J=len(z)-1;
p1=np.zeros((N+1,J+1)); 
p2=np.zeros((N+1,J+1));

# %%
# nice legendre poly's
i=4

plt.plot(legendre(i-2)(z))
plt.plot(legendre(i-1)(z))

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(Z[:,0], Z[:,1], legendre(i-2)(Z[:,0]) * legendre(i-1)(Z[:,1]))

# %%
# build monomial multi indices
monomial={}
x=np.array([0,0])
D = 2
set_size = int(comb(N+D,N))


for i in range(set_size):
    monomial[i] = x.copy()
    x = next_monomial(D,x)
# Out:
# 6

# %%
print(monomial.keys())
# Out:
# dict_keys([0, 1, 2, 3, 4, 5])

# %%
# finding gamma

# %%
# numerical solution in 1D
i=3

f_gamma = lambda x, i: legendre(i-1)(x)* legendre(i-1)(x) 

integrate.quadrature(f_gamma, -1,1, args=(i))[0]
# Out:
# 0.3999999999999999

# %%
# analytical solution in 1 D
2/(2*i-1)
# Out:
# 0.4

# %%
# function to get the multi index gamma from a multi index
def get_gamma(multi_index):
    gammas = np.zeros(len(monomial[multi_index]))
    for index, i in enumerate(monomial[multi_index]):
        gammas[index] = quad(f_gamma, -1,1, args=(i+1))[0]
    return np.product(gammas)

# %%
get_gamma(4)
# Out:
# 0.4444444444444444

# %%
print(legendre(4))

print(legendre(4)[1]) #prints second legendre coefficient
print(legendre(4)[2]) #prints third legendre coefficient
# Out:
#        4             3        2
# 4.375 x + 4.857e-16 x - 3.75 x + 2.429e-16 x + 0.375
# 2.42861286636753e-16
# -3.750000000000001

# %%
'''def numerator(Z1, Z2):
    f_hat_numerator = f_real *  legendre(10)[0] (Z1) * legendre(10)[1](Z2)
    return f_hat_numerator'''

numerator = lambda Z1, Z2: f_real *  legendre(10)[0] (Z1) * legendre(10)[1](Z2)




integrate_num = integrate.dblquad(numerator, -1, 1, -1, 1)
print(integrate_num)

#list(monomial.keys())[multi_index][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sashaboykova/Desktop/Uncertainty Quantification/week 5/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb Cell 22 in <module>
#       <a href='vscode-notebook-cell:/Users/sashaboykova/Desktop/Uncertainty%20Quantification/week%205/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a>     return f_hat_numerator
#       <a href='vscode-notebook-cell:/Users/sashaboykova/Desktop/Uncertainty%20Quantification/week%205/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a> num = numerator
# ---> <a href='vscode-notebook-cell:/Users/sashaboykova/Desktop/Uncertainty%20Quantification/week%205/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb#X35sZmlsZQ%3D%3D?line=9'>10</a> integrate_num = integrate.dblquad(num, -1, 1, -1, 1)
#      <a href='vscode-notebook-cell:/Users/sashaboykova/Desktop/Uncertainty%20Quantification/week%205/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb#X35sZmlsZQ%3D%3D?line=10'>11</a> print(integrate_num)
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:601, in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     597 def temp_ranges(*args):
#     598     return [gfun(args[0]) if callable(gfun) else gfun,
#     599             hfun(args[0]) if callable(hfun) else hfun]
# --> 601 return nquad(func, [temp_ranges, [a, b]], args=args,
#     602         opts={"epsabs": epsabs, "epsrel": epsrel})
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:825, in nquad(func, ranges, args, opts, full_output)
#     823 else:
#     824     opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> 825 return _NQuad(func, ranges, opts, full_output).integrate(*args)
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:879, in _NQuad.integrate(self, *args, **kwargs)
#     877 else:
#     878     f = partial(self.integrate, depth=depth+1)
# --> 879 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#     880               **opt)
#     881 value = quad_r[0]
#     882 abserr = quad_r[1]
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     348 flip, a, b = b < a, min(a, b), max(a, b)
#     350 if weight is None:
# --> 351     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                    points)
#     353 else:
#     354     if points is not None:
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461 if points is None:
#     462     if infbounds == 0:
# --> 463         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464     else:
#     465         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:879, in _NQuad.integrate(self, *args, **kwargs)
#     877 else:
#     878     f = partial(self.integrate, depth=depth+1)
# --> 879 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#     880               **opt)
#     881 value = quad_r[0]
#     882 abserr = quad_r[1]
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     348 flip, a, b = b < a, min(a, b), max(a, b)
#     350 if weight is None:
# --> 351     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                    points)
#     353 else:
#     354     if points is not None:
#
# File /opt/miniconda3/lib/python3.9/site-packages/scipy/integrate/quadpack.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461 if points is None:
#     462     if infbounds == 0:
# --> 463         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464     else:
#     465         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /Users/sashaboykova/Desktop/Uncertainty Quantification/week 5/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb Cell 22 in numerator(Z1, Z2)
#       <a href='vscode-notebook-cell:/Users/sashaboykova/Desktop/Uncertainty%20Quantification/week%205/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> def numerator(Z1, Z2):
# ----> <a href='vscode-notebook-cell:/Users/sashaboykova/Desktop/Uncertainty%20Quantification/week%205/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a>     f_hat_numerator = f_real *  legendre(10)[0] (Z1) * legendre(10)[1](Z2)
#       <a href='vscode-notebook-cell:/Users/sashaboykova/Desktop/Uncertainty%20Quantification/week%205/uncertainty_quantification/04_homework/.ipynb_checkpoints/hw4-checkpoint.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a>     return f_hat_numerator
#
# TypeError: 'numpy.float64' object is not callable

# %%
# get the f_hat

f_hats = np.zeros(len(monomial))
psy = np.zeros(len(monomial))

for multi_index in monomial.keys():
    f_hats[multi_index] = np.dot(f(Z[:,0], Z[:,1]),legendre(monomial[multi_index][0])(Z[:,0]) * legendre(monomial[multi_index][1])(Z[:,1]))/len(Z[:,0]) / get_gamma(multi_index)
    psy[multi_index] = legendre(monomial[multi_index][0])(Z[:,0]) * legendre(monomial[multi_index][1])(Z[:,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [563], in <cell line: 6>()
#       6 for multi_index in monomial.keys():
#       7     f_hats[multi_index] = np.dot(f(Z[:,0], Z[:,1]),legendre(monomial[multi_index][0])(Z[:,0]) * legendre(monomial[multi_index][1])(Z[:,1]))/len(Z[:,0]) / get_gamma(multi_index)
# ----> 8     psy[multi_index] = legendre(monomial[multi_index][0])(Z[:,0]) * legendre(monomial[multi_index][1])(Z[:,1])
#
# ValueError: setting an array element with a sequence.

# %%
f_hats *
# Out:
# array([ 0.15197591, -0.06223162,  0.11117258, -0.02497633,  0.00087642,
#        -0.05366441])

# %%
#estimate f_hat
x, w = np.polynomial.legendre.leggauss(M)

for
