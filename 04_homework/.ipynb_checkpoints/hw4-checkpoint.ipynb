# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from scipy.special import legendre
from scipy.special import hermite
import copy
import pandas as pd
from scipy import integrate
from scipy.special import comb
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from tqdm import tqdm

# %%
'''
https://people.sc.fsu.edu/~jburkardt/py_src/monomial/monomial.py
Finds the next monomial multi-index, as explained in the lecture

'''

def next_monomial(m,x):
    j = 0

    for i in range ( 1, m ):
        if ( 0 < x[i] ):
            j = i
            break

    if ( j == 0 ):
        t = x[0]
        x[0] = 0
        x[m-1] = t + 1
    elif ( j < m - 1 ):
        x[j] = x[j] - 1
        t = x[0] + 1;
        x[0] = 0;
        x[j-1] = x[j-1] + t
    elif ( j == m - 1 ):
        t = x[0]
        x[0] = 0
        x[j-1] = t + 1
        x[j] = x[j] - 1

    return x

# %%
def f(z1, z2):
    return -abs(z1)**3*z2+np.exp(-(z1-0.5)**2-0.25*z2**2)

# %%
M = 1000000
Z = np.zeros((M,2))

Z[:,0] = np.random.uniform(size=M) * 2 - 1
Z[:,1] = np.random.uniform(size=M) * 2 - 1

f_real = f(Z[:,0],Z[:,1])

# %%
x = Z[:,0]
y = f_real

ax1 = sns.jointplot(x=x, y=y)
ax1.ax_joint.cla()
plt.sca(ax1.ax_joint)

plt.hist2d(x, y, bins=(100, 100), cmap=cm.jet);

# %%
x = Z[:,1]
y = f_real

ax1 = sns.jointplot(x=x, y=y)
ax1.ax_joint.cla()
plt.sca(ax1.ax_joint)

plt.hist2d(x, y, bins=(100, 100), cmap=cm.jet);

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
X = Z[1:1000,0]
Y = Z[1:1000,1]
X, Y = np.meshgrid(X, Y)
R = f(X,Y)

surf = ax.plot_surface(X, Y, R, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Customize the z axis.
ax.set_zlim(-.1, 1.5)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(Z[:,0], Z[:,1], f_real)

# %%
N = 2
M = N+1
D=2

# %%
x, w = np.polynomial.legendre.leggauss(M)

# %%
c=np.zeros(N+1); g=np.zeros(N+1);

# %%
# computational grid
l =-1
r=1
dz=0.001;

z=np.linspace(l,r,int((r-l) / dz));
J=len(z)-1;
p1=np.zeros((N+1,J+1)); 
p2=np.zeros((N+1,J+1));

# %%
# nice legendre poly's
i=4

plt.plot(legendre(i-2)(z))
plt.plot(legendre(i-1)(z))

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(Z[:,0], Z[:,1], legendre(i-2)(Z[:,0]) * legendre(i-1)(Z[:,1]))

# %%
# build monomial multi indices
monomial={}
x=np.array([0,0])
D = 2
N=2
set_size = int(comb(N+D,N))

for i in range(set_size):
    monomial[i] = x.copy()
    x = next_monomial(D,x)

# %%
# finding gamma

# %%
# numerical solution in 1D
i=2

f_gamma = lambda x, i: legendre(i-1)(x)* legendre(i-1)(x) 

integrate.quadrature(f_gamma, -1,1, args=(i))[0]
# Out:
# 0.666666666666667

# %%
# analytical solution in 1 D
2/(2*i-1)
# Out:
# 0.6666666666666666

# %%
# function to get the multi index gamma from a multi index
def get_gamma(multi_index):
    gammas = np.zeros(len(monomial[multi_index]))
    for index, i in enumerate(monomial[multi_index]):
        gammas[index] = integrate.quadrature(f_gamma, -1,1, args=(i+1))[0]
    return np.product(gammas)

# %%
def phi(multi_index, Z):
    ans = legendre(monomial[multi_index][0]+1)(Z[0])
    for i in range(1, len(monomial[multi_index])):
        ans*=legendre(monomial[multi_index][i]+1)(Z[i])
        #ans*=legendre(i+1)(Z[i])
    return ans

# %%
def f_hat(z1,z2, multi_index, nothing):
    Z = [z1,z2]
    return f(z1,z2) * phi(multi_index, Z)

# %%
ans = 0
z1=.1
z2=-0.5
Z = np.array([z1,z2])

for multi_index in monomial.keys():
    ans+=((integrate.nquad(f_hat, ((-1,1),(-1,1)), args=(multi_index, 1)) / get_gamma(multi_index)) * phi(multi_index, Z))[0]
    #print(ans)

print(ans)
print(f(z1,z2))
# Out:
# -0.029376371998234924
# 0.8010150067502286

# %%
z1 = np.random.uniform(size=100) * 2 -1
z2 = np.random.uniform(size=100) * 2 -1

# %%
y = np.zeros(z1.shape)
for i in tqdm(range(len(z1))):
    ans=0
    Z = np.array([z1[i],z2[i]])
    for multi_index in monomial.keys():
        ans+=((integrate.nquad(f_hat, ((-1,1),(-1,1)), args=(multi_index, 1)))[0] * (1/get_gamma(multi_index)))* phi(multi_index, Z)

    y[i] = ans
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:50<00:00,  1.10s/it]

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(z1,z2, y)

# %%
M = 1000000
Z = np.zeros((M,2))

Z[:,0] = np.random.uniform(size=M) * 2 - 1
Z[:,1] = np.random.uniform(size=M) * 2 - 1

f_real = f(Z[:,0],Z[:,1])

ax = plt.axes(projection='3d')
ax.scatter3D(Z[:,0], Z[:,1], f_real)
